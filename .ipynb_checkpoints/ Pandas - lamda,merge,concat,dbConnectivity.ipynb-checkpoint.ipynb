# %%
import pandas as pd

# %%
df = pd.read_csv('employee2.csv')

# %%
df
# Out:
#    eno    ename  age
# 0    1    nitya   20
# 1    2  namasvi   21
# 2    3     sonu   33
# 3    4    vidya   20
# 4    6     sonu   33
# 5    7    Shalu   20

# %%
df['age_double']= df['age']*2

# %%
df['age_double']
# Out:
# 0    40
# 1    42
# 2    66
# 3    40
# 4    66
# 5    40
# Name: age_double, dtype: int64

# %%
df['hf_age']= df['age_double'].apply(lambda x:x/2)

# %%
df['hf_age']
# Out:
# 0    20.0
# 1    21.0
# 2    33.0
# 3    20.0
# 4    33.0
# 5    20.0
# Name: hf_age, dtype: float64

# %%
df['ename_upper']= df['ename'].apply(lambda x:x.upper())

# %%
df
# Out:
#    eno    ename  age  age_double  hf_age ename_upper
# 0    1    nitya   20          40    20.0       NITYA
# 1    2  namasvi   21          42    21.0     NAMASVI
# 2    3     sonu   33          66    33.0        SONU
# 3    4    vidya   20          40    20.0       VIDYA
# 4    6     sonu   33          66    33.0        SONU
# 5    7    Shalu   20          40    20.0       SHALU

# %%
df['thrice_age']=df['age'].apply(lambda x:x*3)

# %%
df
# Out:
#    eno    ename  age  age_double  hf_age ename_upper  thrice_age
# 0    1    nitya   20          40    20.0       NITYA          60
# 1    2  namasvi   21          42    21.0     NAMASVI          63
# 2    3     sonu   33          66    33.0        SONU          99
# 3    4    vidya   20          40    20.0       VIDYA          60
# 4    6     sonu   33          66    33.0        SONU          99
# 5    7    Shalu   20          40    20.0       SHALU          60

# %%
df_emp = pd.read_csv('employee2.csv')

# %%
df_sal= pd.read_csv('empSal.csv')

# %%
df_emp
# Out:
#    eno    ename  age
# 0    1    nitya   20
# 1    2  namasvi   21
# 2    3     sonu   33
# 3    4    vidya   20
# 4    6     sonu   33
# 5    7    Shalu   20

# %%
df_sal
# Out:
#    eno   sal
# 0    1  2000
# 1    2  3000
# 2    3  4000
# 3    6  5000

# %%
df_emp.merge(df_sal,on='eno',how='inner')
# Out:
#    eno    ename  age   sal
# 0    1    nitya   20  2000
# 1    2  namasvi   21  3000
# 2    3     sonu   33  4000
# 3    6     sonu   33  5000

# %%
df_emp.merge(df_sal,on='eno',how='left')
# Out:
#    eno    ename  age     sal
# 0    1    nitya   20  2000.0
# 1    2  namasvi   21  3000.0
# 2    3     sonu   33  4000.0
# 3    4    vidya   20     NaN
# 4    6     sonu   33  5000.0
# 5    7    Shalu   20     NaN

# %%
df_emp.merge(df_sal,on='eno',how='right')
# Out:
#    eno    ename  age   sal
# 0    1    nitya   20  2000
# 1    2  namasvi   21  3000
# 2    3     sonu   33  4000
# 3    6     sonu   33  5000

# %%
df1 = pd.read_csv('employee2.csv')

# %%
df2 = pd.read_csv('employee3.csv')

# %%
df1
# Out:
#    eno    ename  age
# 0    1    nitya   20
# 1    2  namasvi   21
# 2    3     sonu   33
# 3    4    vidya   20
# 4    6     sonu   33
# 5    7    Shalu   20

# %%
df2
# Out:
#    eno  ename  age
# 0    1  nitya   52
# 1    3   sonu   10
# 2    6  Rahul   33
# 3    7  Aarav   12

# %%
pd.concat([df1,df2],axis=0)
# Out:
#    eno    ename  age
# 0    1    nitya   20
# 1    2  namasvi   21
# 2    3     sonu   33
# 3    4    vidya   20
# 4    6     sonu   33
# 5    7    Shalu   20
# 0    1    nitya   52
# 1    3     sonu   10
# 2    6    Rahul   33
# 3    7    Aarav   12

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    eno    ename  age  eno  ename   age
# 0    1    nitya   20  1.0  nitya  52.0
# 1    2  namasvi   21  3.0   sonu  10.0
# 2    3     sonu   33  6.0  Rahul  33.0
# 3    4    vidya   20  7.0  Aarav  12.0
# 4    6     sonu   33  NaN    NaN   NaN
# 5    7    Shalu   20  NaN    NaN   NaN

# %%
pd.read_csv("employee2.csv", names=[ 'empName','myage'], header=0)
# Out:
#    empName  myage
# 1    nitya     20
# 2  namasvi     21
# 3     sonu     33
# 4    vidya     20
# 6     sonu     33
# 7    Shalu     20

# %%
pd.read_csv("employee2.csv", usecols=['eno', 'age'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 pd.read_csv("employee2.csv", usecols=['eno1', 'age'])
#
# File C:\Python3.10\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File C:\Python3.10\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File C:\Python3.10\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File C:\Python3.10\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File C:\Python3.10\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:140, in CParserWrapper.__init__(self, src, **kwds)
#     136 assert self.orig_names is not None
#     137 if self.usecols_dtype == "string" and not set(usecols).issubset(
#     138     self.orig_names
#     139 ):
# --> 140     self._validate_usecols_names(usecols, self.orig_names)
#     142 # error: Cannot determine type of 'names'
#     143 if len(self.names) > len(usecols):  # type: ignore[has-type]
#     144     # error: Cannot determine type of 'names'
#
# File C:\Python3.10\Lib\site-packages\pandas\io\parsers\base_parser.py:979, in ParserBase._validate_usecols_names(self, usecols, names)
#     977 missing = [c for c in usecols if c not in names]
#     978 if len(missing) > 0:
# --> 979     raise ValueError(
#     980         f"Usecols do not match columns, columns expected but not found: "
#     981         f"{missing}"
#     982     )
#     984 return usecols
#
# ValueError: Usecols do not match columns, columns expected but not found: ['eno1']
