# %%
import pandas as pd

# %%
df=pd.read_csv("employee2.csv")

# %%
df
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 4    5    kaira   NaN
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
fil = df['age'] >=30

# %%
df[fil]
# Out:
#    eno ename   age
# 2    3  sonu  33.0
# 5    6  sonu  33.0

# %%
df
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 4    5    kaira   NaN
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
fillna = df.fillna(18)

# %%
fillna
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 4    5    kaira  18.0
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
df
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 4    5    kaira   NaN
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
 df.dropna()
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
df
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 4    5    kaira   NaN
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
df
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 4    5    kaira   NaN
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
df= df.rename(columns={"eno":"empno"})

# %%
df
# Out:
#    empno    ename   age
# 0      1    nitya  20.0
# 1      2  namasvi  21.0
# 2      3     sonu  33.0
# 3      4    vidya  20.0
# 4      5    kaira   NaN
# 5      6     sonu  33.0
# 6      7    Shalu  20.0

# %%
df
# Out:
#    empno    ename   age
# 0      1    nitya  20.0
# 1      2  namasvi  21.0
# 2      3     sonu  33.0
# 3      4    vidya  20.0
# 4      5    kaira   NaN
# 5      6     sonu  33.0
# 6      7    Shalu  20.0

# %%
df = pd.read_csv('employee2.csv')

# %%
df
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 4    5    kaira   NaN
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
df['age'].fillna(17,inplace=False)
# Out:
# 0    20.0
# 1    21.0
# 2    33.0
# 3    20.0
# 4    17.0
# 5    33.0
# 6    20.0
# Name: age, dtype: float64

# %%
df
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 4    5    kaira   NaN
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
df['age'].fillna(12 , inplace=False)
# Out:
# 0    20.0
# 1    21.0
# 2    33.0
# 3    20.0
# 4    12.0
# 5    33.0
# 6    20.0
# Name: age, dtype: float64

# %%
df
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 4    5    kaira   NaN
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
df
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 4    5    kaira   NaN
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
df = pd.read_csv("employee2.csv")

# %%
df
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 4    5    kaira   NaN
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
fillna = df['age'].fillna(12,inplace=False)

# %%
fillna
# Out:
# 0    20.0
# 1    21.0
# 2    33.0
# 3    20.0
# 4    12.0
# 5    33.0
# 6    20.0
# Name: age, dtype: float64

# %%
df
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 4    5    kaira   NaN
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
df = pd.read_csv("employee2.csv")

# %%
df
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 4    5    kaira   NaN
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
df['age'].fillna(13,inplace=True)
# Out:
# C:\Users\sonu malewar\AppData\Local\Temp\ipykernel_11584\2876344923.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(13,inplace=True)

# %%
df
# Out:
#    eno    ename   age
# 0    1    nitya  20.0
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 3    4    vidya  20.0
# 4    5    kaira  13.0
# 5    6     sonu  33.0
# 6    7    Shalu  20.0

# %%
df['age'] > 20
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# Name: age, dtype: bool

# %%
filtered_data = df[df['age'] > 20]

# %%
filtered_data
# Out:
#    eno    ename   age
# 1    2  namasvi  21.0
# 2    3     sonu  33.0
# 5    6     sonu  33.0
