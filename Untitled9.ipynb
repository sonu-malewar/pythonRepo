# %%
import pandas as pd

# %%
df = pd.read_csv('secFile.csv',delimiter='|')

# %%
df
# Out:
#    eno   ename   age
# 0    1    Amar  24.0
# 1    2   Akash  20.0
# 2    3   Rohan  20.0
# 3    4   Rajiv  24.0
# 4    5   Akash   NaN
# 5    6  Sonali  42.0
# 6    7     NaN  26.0
# 7    8   Rohan  23.0
# 8    9  Ankita  15.0
# 9   10   Ritik  20.0

# %%
df = pd.read_csv('secFile.csv',delimiter='|',usecols=['eno','ename'])

# %%
df
# Out:
#    eno   ename
# 0    1    Amar
# 1    2   Akash
# 2    3   Rohan
# 3    4   Rajiv
# 4    5   Akash
# 5    6  Sonali
# 6    7     NaN
# 7    8   Rohan
# 8    9  Ankita
# 9   10   Ritik

# %%
df = pd.read_csv('secFile.csv',delimiter='|',usecols=['eno','ename'],index_col='ename')

# %%
df
# Out:
#         eno
# ename
# Amar      1
# Akash     2
# Rohan     3
# Rajiv     4
# Akash     5
# Sonali    6
# NaN       7
# Rohan     8
# Ankita    9
# Ritik    10

# %%
df
# Out:
#         eno
# ename
# Amar      1
# Akash     2
# Rohan     3
# Rajiv     4
# Akash     5
# Sonali    6
# NaN       7
# Rohan     8
# Ankita    9
# Ritik    10

# %%
df = pd.read_csv('secFile.csv',delimiter='|',dtype={'age':str},index_col='age')

# %%
df
# Out:
#      eno   ename
# age
# 24     1    Amar
# 20     2   Akash
# 20     3   Rohan
# 24     4   Rajiv
# NaN    5   Akash
# 42     6  Sonali
# 26     7     NaN
# 23     8   Rohan
# 15     9  Ankita
# 20    10   Ritik

# %%
for chunk in pd.read_csv('secFile.csv',delimiter='|',chunksize=2):
    print(chunk)
# Out:
#    eno  ename  age
# 0    1   Amar   24
# 1    2  Akash   20
#    eno  ename  age
# 2    3  Rohan   20
# 3    4  Rajiv   24
#    eno   ename   age
# 4    5   Akash   NaN
# 5    6  Sonali  42.0
#    eno  ename  age
# 6    7    NaN   26
# 7    8  Rohan   23
#    eno   ename  age
# 8    9  Ankita   15
# 9   10   Ritik   20

# %%
df = pd.read_csv('secFile.csv',delimiter = '|',skiprows=5)

# %%
df
# Out:
#     5   Akash  Unnamed: 2
# 0   6  Sonali          42
# 1   7     NaN          26
# 2   8   Rohan          23
# 3   9  Ankita          15
# 4  10   Ritik          20

# %%
df = pd.read_csv('secFile.csv',delimiter = '|',names=['empNo','empName','empAge'])

# %%
df
# Out:
#    empNo empName empAge
# 0    eno   ename    age
# 1      1    Amar     24
# 2      2   Akash     20
# 3      3   Rohan     20
# 4      4   Rajiv     24
# 5      5   Akash    NaN
# 6      6  Sonali     42
# 7      7     NaN     26
# 8      8   Rohan     23
# 9      9  Ankita     15
# 10    10   Ritik     20

# %%
df = pd.read_csv('secFile.csv',delimiter = '|',names=['empNo','empName','empAge'],skiprows=3,nrows=4)

# %%
df
# Out:
#    empNo empName  empAge
# 0      3   Rohan    20.0
# 1      4   Rajiv    24.0
# 2      5   Akash     NaN
# 3      6  Sonali    42.0

# %%
df = pd.read_csv('secFile.csv',delimiter = '|',names=['empNo','empName','empAge'],dtype={'empAge':str},skiprows=3,nrows=4)

# %%
df
# Out:
#    empNo empName empAge
# 0      3   Rohan     20
# 1      4   Rajiv     24
# 2      5   Akash    NaN
# 3      6  Sonali     42

# %%
df = pd.read_csv('secFile.csv',delimiter = '|')

# %%
df1=df.iloc[3:8:2]

# %%
df1
# Out:
#    eno   ename   age
# 3    4   Rajiv  24.0
# 5    6  Sonali  42.0
# 7    8   Rohan  23.0

# %%
df
# Out:
#    eno   ename   age
# 0    1    Amar  24.0
# 1    2   Akash  20.0
# 2    3   Rohan  20.0
# 3    4   Rajiv  24.0
# 4    5   Akash   NaN
# 5    6  Sonali  42.0
# 6    7     NaN  26.0
# 7    8   Rohan  23.0
# 8    9  Ankita  15.0
# 9   10   Ritik  20.0

# %%
df.sort_values(by='age')
# Out:
#    eno   ename   age
# 8    9  Ankita  15.0
# 1    2   Akash  20.0
# 2    3   Rohan  20.0
# 9   10   Ritik  20.0
# 7    8   Rohan  23.0
# 3    4   Rajiv  24.0
# 0    1    Amar  24.0
# 6    7     NaN  26.0
# 5    6  Sonali  42.0
# 4    5   Akash   NaN

# %%
df.sort_values(by=['age','eno'],ascending=[True,False])
# Out:
#    eno   ename   age
# 8    9  Ankita  15.0
# 9   10   Ritik  20.0
# 2    3   Rohan  20.0
# 1    2   Akash  20.0
# 7    8   Rohan  23.0
# 3    4   Rajiv  24.0
# 0    1    Amar  24.0
# 6    7     NaN  26.0
# 5    6  Sonali  42.0
# 4    5   Akash   NaN

# %%
df
# Out:
#    eno   ename   age
# 0    1    Amar  24.0
# 1    2   Akash  20.0
# 2    3   Rohan  20.0
# 3    4   Rajiv  24.0
# 4    5   Akash   NaN
# 5    6  Sonali  42.0
# 6    7     NaN  26.0
# 7    8   Rohan  23.0
# 8    9  Ankita  15.0
# 9   10   Ritik  20.0

# %%
df.groupby('ename')['age'].max()
# Out:
# ename
# Akash     20.0
# Amar      24.0
# Ankita    15.0
# Rajiv     24.0
# Ritik     20.0
# Rohan     23.0
# Sonali    42.0
# Name: age, dtype: float64

# %%
df.groupby('ename')['age'].agg(['min','max()','count()'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.groupby('ename')['age'].agg(['min()','max()','count()'])
#
# File C:\Python3.10\Lib\site-packages\pandas\core\groupby\generic.py:257, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     255 kwargs["engine"] = engine
#     256 kwargs["engine_kwargs"] = engine_kwargs
# --> 257 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     258 if relabeling:
#     259     # columns is not narrowed by mypy from relabeling flag
#     260     assert columns is not None  # for mypy
#
# File C:\Python3.10\Lib\site-packages\pandas\core\groupby\generic.py:362, in SeriesGroupBy._aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     360     for idx, (name, func) in enumerate(arg):
#     361         key = base.OutputKey(label=name, position=idx)
# ...
